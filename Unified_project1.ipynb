# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\mahesh\Documents\Mahesh\Data_Analytics\Uninfied mentor\Project\Daily Household Transactions.csv')
data
# Out:
#                   Date                   Mode        Category  \
# 0     20-09-2018 12:04                   Cash  Transportation
# 1     20-09-2018 12:03                   Cash            Food
# 2           19-09-2018  Saving Bank account 1    subscription
# 3     17-09-2018 23:41  Saving Bank account 1    subscription
# 4     16-09-2018 17:15                   Cash       Festivals
# ...                ...                    ...             ...
# 2456        01-01-2015                   Cash  Transportation
# 2457        01-01-2015                   Cash  Transportation
# 2458        01-01-2015                   Cash  Transportation
# 2459        01-01-2015                   Cash            Food
# 2460        01-01-2015                   Cash  Transportation
#
#                   Subcategory                                  Note  Amount  \
# 0                       Train                  2 Place 5 to Place 0    30.0
# ...

# %%
# print(data.head())
# data.tail()
data.shape
# #data.info()
# Out:
# (2461, 8)

# %%
#data description
data.describe()
# Out:
#               Amount
# count    2461.000000
# mean     2751.145380
# std     12519.615804
# min         2.000000
# 25%        35.000000
# 50%       100.000000
# 75%       799.000000
# max    250000.000000

# %%
#data cleaning---------------------------------------------------------------------------------------

#checking for null values
data.isnull().sum()
# Out:
# Date                0
# Mode                0
# Category            0
# Subcategory       635
# Note              521
# Amount              0
# Income/Expense      0
# Currency            0
# dtype: int64

# %%
#
columns = list(data)
columns
# Out:
# ['Date',
#  'Mode',
#  'Category',
#  'Subcategory',
#  'Note',
#  'Amount',
#  'Income/Expense',
#  'Currency']

# %%
#filling null values with 0

(data[columns[1:8]] == 0).sum()
# Out:
# Mode              0
# Category          0
# Subcategory       0
# Note              0
# Amount            0
# Income/Expense    0
# Currency          0
# dtype: int64

# %%
#filling null values with 'Unknown' for categorical columns
data['Subcategory'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\mahesh\AppData\Local\Temp\ipykernel_15936\402884515.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Subcategory'].fillna('Unknown', inplace=True)

# %%
data.head(10)
# Out:
#                Date                   Mode        Category  \
# 0  20-09-2018 12:04                   Cash  Transportation
# 1  20-09-2018 12:03                   Cash            Food
# 2        19-09-2018  Saving Bank account 1    subscription
# 3  17-09-2018 23:41  Saving Bank account 1    subscription
# 4  16-09-2018 17:15                   Cash       Festivals
# 5  15-09-2018 06:34            Credit Card    subscription
# 6  14-09-2018 05:39                   Cash  Transportation
# 7  13-09-2018 21:35  Saving Bank account 1  Transportation
# 8  13-09-2018 21:01            Credit Card           Other
# 9  13-09-2018 21:01                   Cash            Food
#
#                Subcategory                                      Note  Amount  \
# 0                    Train                      2 Place 5 to Place 0    30.0
# 1                   snacks               Idli medu Vada mix 2 plates    60.0
# 2                  Netflix                      1 month subscription   199.0
# ...

# %%
data.dropna(subset=['Date', 'Amount'], inplace=True)
data
# Out:
#                   Date                   Mode        Category  \
# 0     20-09-2018 12:04                   Cash  Transportation
# 1     20-09-2018 12:03                   Cash            Food
# 2           19-09-2018  Saving Bank account 1    subscription
# 3     17-09-2018 23:41  Saving Bank account 1    subscription
# 4     16-09-2018 17:15                   Cash       Festivals
# ...                ...                    ...             ...
# 2456        01-01-2015                   Cash  Transportation
# 2457        01-01-2015                   Cash  Transportation
# 2458        01-01-2015                   Cash  Transportation
# 2459        01-01-2015                   Cash            Food
# 2460        01-01-2015                   Cash  Transportation
#
#                   Subcategory                                  Note  Amount  \
# 0                       Train                  2 Place 5 to Place 0    30.0
# ...

# %%
#converting datatypes
data['Date'] = pd.to_datetime(data['Date'], format='mixed', dayfirst=True)
data['Amount'] = data['Amount'].astype(float)
data['Mode'] = data['Mode'].astype(str)
data['Category'] = data['Category'].astype(str)
data['Note'] = data['Note'].astype(str)
data
# Out:
#                     Date                   Mode        Category  \
# 0    2018-09-20 12:04:00                   Cash  Transportation
# 1    2018-09-20 12:03:00                   Cash            Food
# 2    2018-09-19 00:00:00  Saving Bank account 1    subscription
# 3    2018-09-17 23:41:00  Saving Bank account 1    subscription
# 4    2018-09-16 17:15:00                   Cash       Festivals
# ...                  ...                    ...             ...
# 2456 2015-01-01 00:00:00                   Cash  Transportation
# 2457 2015-01-01 00:00:00                   Cash  Transportation
# 2458 2015-01-01 00:00:00                   Cash  Transportation
# 2459 2015-01-01 00:00:00                   Cash            Food
# 2460 2015-01-01 00:00:00                   Cash  Transportation
#
#                   Subcategory                                  Note  Amount  \
# 0                       Train                  2 Place 5 to Place 0    30.0
# ...

# %%
#Remoiving duplicates
data.drop_duplicates(inplace=True)
data
# Out:
#                     Date                   Mode        Category  \
# 0    2018-09-20 12:04:00                   Cash  Transportation
# 1    2018-09-20 12:03:00                   Cash            Food
# 2    2018-09-19 00:00:00  Saving Bank account 1    subscription
# 3    2018-09-17 23:41:00  Saving Bank account 1    subscription
# 4    2018-09-16 17:15:00                   Cash       Festivals
# ...                  ...                    ...             ...
# 2456 2015-01-01 00:00:00                   Cash  Transportation
# 2457 2015-01-01 00:00:00                   Cash  Transportation
# 2458 2015-01-01 00:00:00                   Cash  Transportation
# 2459 2015-01-01 00:00:00                   Cash            Food
# 2460 2015-01-01 00:00:00                   Cash  Transportation
#
#                   Subcategory                                  Note  Amount  \
# 0                       Train                  2 Place 5 to Place 0    30.0
# ...

# %%
data.dtypes
# Out:
# Date              datetime64[ns]
# Mode                      object
# Category                  object
# Subcategory               object
# Note                      object
# Amount                   float64
# Income/Expense            object
# Currency                  object
# dtype: object

# %%
#EDA--------------------------------------------------------------------------------------------

#Summary statistics
data.describe()
# Out:
#                                 Date         Amount
# count                           2452    2452.000000
# mean   2017-04-03 18:15:18.670473216    2757.976664
# min              2015-01-01 00:00:00       2.000000
# 25%              2016-10-17 03:45:15      35.000000
# 50%              2017-06-23 21:31:30     100.000000
# 75%              2018-01-16 08:36:30     784.500000
# max              2018-09-20 12:04:00  250000.000000
# std                              NaN   12542.057491

# %%
#Distribution of transaction amounts
plt.figure(figsize=(10, 6))
sns.histplot(data['Amount'], bins=50, kde=True)
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# %%
# Transaction counts by category
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Category', order=data['Category'].value_counts().iloc[:5].index)
plt.title('Transaction Counts by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
data["Category"].value_counts()
# Out:
# Category
# Food                         906
# Transportation               307
# Household                    176
# subscription                 143
# Other                        126
# Investment                   101
# Health                        94
# Family                        71
# Apparel                       47
# Salary                        43
# Money transfer                43
# Recurring Deposit             41
# Gift                          30
# Public Provident Fund         29
# Equity Mutual Fund E          22
# Beauty                        22
# Gpay Reward                   21
# Education                     18
# Saving Bank account 1         17
# maid                          17
# Festivals                     16
# Equity Mutual Fund A          14
# Equity Mutual Fund F          13
# Dividend earned on Shares     12
# Interest                      12
# Culture                       11
# Small Cap fund 2              10
# Small cap fund 1              10
# ...

# %%
# Transaction counts by type
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Income/Expense')
plt.title('Transaction Counts by Type')
plt.xlabel('Income/Expense')
plt.ylabel('Count')
plt.show()
data["Income/Expense"].value_counts()
# Out:
# Income/Expense
# Expense         2173
# Transfer-Out     154
# Income           125
# Name: count, dtype: int64

# %%
# Transaction counts by type
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Mode',order=data['Mode'].value_counts().index)
plt.title('Transaction Counts by Type_Income/Expense')
plt.xlabel('Income/Expense')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
data["Mode"].value_counts()
# Out:
# Mode
# Saving Bank account 1    1215
# Cash                     1045
# Credit Card               162
# Equity Mutual Fund B       11
# Share Market Trading        5
# Saving Bank account 2       5
# Recurring Deposit           3
# Debit Card                  2
# Equity Mutual Fund C        1
# Equity Mutual Fund A        1
# Equity Mutual Fund D        1
# Fixed Deposit               1
# Name: count, dtype: int64

# %%
data["Subcategory"].unique()
# Out:
# array(['Train', 'snacks', 'Netflix', 'Mobile Service Provider',
#        'Ganesh Pujan', 'Tata Sky', 'auto', 'Unknown', 'Grocery', 'Lunch',
#        'Milk', 'Pocket money', 'Laundry', 'breakfast', 'Dinner', 'Sweets',
#        'Kirana', 'Ice cream', 'curd', 'Biscuits', 'Rajgira ladu',
#        'Navratri', 'train', 'Tea', 'flour mill', 'Appliances',
#        'home decor', 'grooming', 'Health', 'Clothing', 'clothes', 'Home',
#        'chocolate', 'Medicine', 'Eating out', 'Movie', 'vegetables',
#        'fruits', 'Potato', 'Onions', 'Taxi', 'Hardware', 'Eggs', 'Bread',
#        'Petrol', 'Hospital', 'Mahanagar Gas', 'Lab Tests', 'Bus',
#        'Travels', 'Kitchen', 'Footwear', 'Entry Fees', 'gadgets',
#        'Accessories', 'misc', 'Stationary', 'Newspaper', 'Toiletries',
#        'Bike', 'beverage', 'makeup', 'Books', 'Holi', 'Courier',
#        'Leisure', 'Updation', 'Amazon Prime', 'Edtech Course', 'Hotstar',
# ...

# %%
plt.figure(figsize = (12,8))
sns.countplot(data = data, x = "Subcategory", order =
data["Subcategory"].value_counts().iloc[:10].index)
plt.xticks(rotation = 90)
plt.show()
data["Subcategory"].value_counts()
# Out:
# Subcategory
# Unknown            629
# Milk               162
# auto               142
# snacks             115
# Grocery            113
#                   ...
# Books                1
# ropeway              1
# OTT Platform         1
# School supplies      1
# Makeup               1
# Name: count, Length: 91, dtype: int64

# %%
data["Note"].nunique()
# Out:
# 1058

# %%
data["Currency"].value_counts()
# Out:
# Currency
# INR    2452
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = data, x = "Amount", y = "Category", order =
data["Category"].value_counts().iloc[:5].index)
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = data, x = "Amount", y = "Subcategory", order =
data["Subcategory"].value_counts().iloc[:10].index)
plt.xlim(0, 3500)
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = data, x = "Amount", y = "Income/Expense")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=data,x = 'Income/Expense', y = 'Mode')
plt.title('Income/Expense by Category and Mode')
# Out:
# Text(0.5, 1.0, 'Income/Expense by Category and Mode')

# %%
#Time Series Analysis------------------------------------------------------

# Resample data to monthly frequency
monthly_data = data.resample('M', on='Date').sum()
plt.figure(figsize=(14, 7))
plt.plot(monthly_data.index, monthly_data['Amount'], marker='o')
plt.title('Monthly Transaction Amounts')
plt.xlabel('Month')
plt.ylabel('Total Amount')
plt.grid(True)
plt.show()
# Out:
# C:\Users\mahesh\AppData\Local\Temp\ipykernel_15936\2354312066.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data = data.resample('M', on='Date').sum()

# %%
# Daily trends
daily_data = data.groupby(data['Date'].dt.date)['Amount'].sum()
plt.figure(figsize=(14, 7))
plt.plot(daily_data.index, daily_data.values, marker='o', color = 'orange')
plt.title('Daily Transaction Amounts')
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.grid(True)
plt.show()

# %%
#Correlation Analysis-----------------------------------------------------

#Analyzing the correlation between transaction categories and amounts.
# Create a pivot table for correlation analysis
data.pivot_table(
    ["Category", "Amount"],
    ["Date"],
    aggfunc = "sum",
).head(100)
# pivot_table = data.pivot_table(index='Date', columns='Category', values='Amount',
# aggfunc='sum', fill_value=0)
# pivot_table
# Out:
#                       Amount  \
# Date
# 2015-01-01 00:00:00    952.0
# 2015-01-02 00:00:00  10104.0
# 2015-01-03 00:00:00    622.0
# 2015-01-04 00:00:00  10230.0
# 2015-01-05 00:00:00   5551.0
# ...                      ...
# 2015-03-18 09:25:00     26.0
# 2015-03-18 10:56:00     20.0
# 2015-03-18 13:22:00     25.0
# 2015-03-18 18:27:00     53.0
# 2015-03-19 16:08:00     50.0
#
#                                                               Category
# Date
# 2015-01-01 00:00:00  FoodTransportationTransportationCultureFoodTra...
# 2015-01-02 00:00:00                                  FoodOtherFoodFood
# 2015-01-03 00:00:00                                      OtherFoodFood
# 2015-01-04 00:00:00                                  FoodFoodFoodOther
# 2015-01-05 00:00:00                                OtherOtherFoodOther
# ...                                                                ...
# 2015-03-18 09:25:00                                               Food
# ...

# %%
data["Amount"].hist(figsize=(10, 6))
# Out:
# <Axes: >

# %%
data.hist(color = "k",
        bins = 30,
        figsize = (15, 5))
plt.show()

# %%
# data.iloc[:5].boxplot(column = "Amount",
#         by = ["Category"],
#         figsize = (14, 7))
# plt.xticks(rotation=90)
# plt.show()

# %%
corr = data.select_dtypes(include='number').corr()
corr
# Out:
#         Amount
# Amount     1.0

# %%
# Create a pivot table for correlation analysis
pivot_table = data.pivot_table(index='Date', columns='Category', values='Amount', aggfunc='sum', fill_value=0)

# Calculate correlation matrix
correlation_matrix = pivot_table.corr()

# Plot correlation heatmap
plt.figure(figsize=(40, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Transaction Categories')
plt.show()
